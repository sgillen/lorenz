# %%
from seagul.rl.ars.ars_pipe import ars
from seagul.nn import MLP
import torch
import matplotlib.pyplot as plt
from seagul.mesh import variation_dim
import time
import copy
import gym

import xarray as xr 
import pandas as pd
import numpy as np

def identity(rews,obs,acts):
    return rews

def shrinkdim(rews, obs, acts):
    return rews/variation_dim(obs)

def growdim(rews, obs, acts):
    return rews*variation_dim(obs)

def rough_measure(x):
    d = torch.stack([x[t,:] - x[t-1,:] for t in range(1,x.shape[0])])
    return d.std()#$/(torch.abs(d.mean()))

def rmul(rews, obs, acts):
    return rews*rough_measure(obs)

def rdiv(rews, obs, acts):
    return rews/rough_measure(obs)


exp_names = ['standard', 'rmul']
exp_fns = [identity, rmul]


#exp_names = ['standard','vardiv','varmul','rmul','rdiv']
#exp_fns = [identity, shrinkdim, growdim, rmul, rdiv]
env_name = "HalfCheetah-v2"

name="mjhc_longermul"
policy_dict = torch.load("./data/" + name + ".pol_dict")
data = torch.load("./data/" + name +".data")
data_post = torch.load("./data/" + name + ".post_data")

def do_rollout(env, policy, render=False):
    torch.autograd.set_grad_enabled(False)

    act_list = []
    obs_list = []
    rew_list = []

    dtype = torch.float32
    obs = env.reset()
    done = False
    cur_step = 0

    while not done:
        obs = torch.as_tensor(obs, dtype=dtype).detach()
        obs_list.append(obs.clone())

        act = policy(obs)
        obs, rew, done, _ = env.step(act.numpy())
        if render:
            env.render()
            time.sleep(.02)

        act_list.append(torch.as_tensor(act.clone()))
        rew_list.append(rew)

        cur_step += 1

    ep_length = len(rew_list)
    ep_obs = torch.stack(obs_list)
    ep_act = torch.stack(act_list)
    ep_rew = torch.tensor(rew_list, dtype=dtype)
    ep_rew = ep_rew.reshape(-1, 1)

    torch.autograd.set_grad_enabled(True)
    return ep_obs, ep_act, ep_rew, ep_length, None
# Out:
# /home/sgillen/miniconda3/envs/baselines/lib/python3.6/site-packages/torch/serialization.py:657: SourceChangeWarning: source code of class 'torch.nn.modules.activation.ReLU' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# /home/sgillen/miniconda3/envs/baselines/lib/python3.6/site-packages/torch/serialization.py:657: SourceChangeWarning: source code of class 'torch.nn.modules.linear.Linear' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)

# %%
means = data.mean(dim="Trial")
stds = data.std(dim="Trial")

plt.plot(means.T)
plt.legend(exp_names)
ci = stds

for mean, c in zip(means, ci):
    plt.fill_between([t for t in range(len(mean))], (mean-c), (mean+c), alpha=.5)
plt.title("\"True\" Reward")

plt.figure()
means = data_post.mean(dim="Trial")
stds = data_post.std(dim="Trial")

plt.plot(means.T)
plt.legend(exp_names)
ci = stds

for mean, c in zip(means, ci):
    plt.fill_between([t for t in range(len(mean))], (mean-c), (mean+c), alpha=.5)
plt.title("Post Processed")
plt.figure()
    
for exp_name in exp_names:  
    plt.plot(data.loc[exp_name].T)
    plt.title(exp_name)
    plt.figure()

# %%
import gym
import pybullet_envs
env = gym.make(env_name)

# %%
post_name = "standard"; seed = 0
o,a,r,l,_ = do_rollout(env,policy_dict[post_name][seed], render=True)

print("reward:", sum(r))
print("variation_dim: ", variation_dim(o))
print("roughness: ", rough_measure(o))
plt.plot(o)
plt.figure()
plt.plot(a)

#import scipy.io 
#import os

#os.makedirs(f"./data/j/{name}/{exp_name}/{seed}", exist_ok=True)
#scipy.io.savemat(f"./data/j/{name}/{exp_name}/{seed}/{run}.mat", mdict = {"obs":o, "act":a, "rew":r})
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-124-d16b1acd69ea> in <module>
#       1 post_name = "standard"; seed = 0
# ----> 2 o,a,r,l,_ = do_rollout(env,policy_dict[post_name][seed], render=True)
#       3
#       4 print("reward:", sum(r))
#       5 print("variation_dim: ", variation_dim(o))
#
# <ipython-input-121-b1cf93e137a4> in do_rollout(env, policy, render)
#      64         obs, rew, done, _ = env.step(act.numpy())
#      65         if render:
# ---> 66             env.render()
#      67             time.sleep(.02)
#      68
#
# ~/miniconda3/envs/baselines/lib/python3.6/site-packages/gym/core.py in render(self, mode, **kwargs)
#     242
#     243     def render(self, mode='human', **kwargs):
# --> 244         return self.env.render(mode, **kwargs)
#     245
#     246     def close(self):
#
# ~/miniconda3/envs/baselines/lib/python3.6/site-packages/gym/envs/mujoco/mujoco_env.py in render(self, mode, width, height)
#     116             return data[::-1, :]
#     117         elif mode == 'human':
# --> 118             self._get_viewer(mode).render()
#     119
#     120     def close(self):
#
# ~/work/external/mujoco-py/mujoco_py/mjviewer.py in render(self)
#     193                 self._loop_count = 1
#     194             while self._loop_count > 0:
# --> 195                 render_inner_loop(self)
#     196                 self._loop_count -= 1
#     197         # Markers and overlay are regenerated in every pass.
#
# ~/work/external/mujoco-py/mujoco_py/mjviewer.py in render_inner_loop(self)
#     169                 self._create_full_overlay()
#     170
# --> 171             super().render()
#     172             if self._record_video:
#     173                 frame = self._read_pixels_as_in_window()
#
# ~/work/external/mujoco-py/mujoco_py/mjviewer.py in render(self)
#      51
#      52         with self._gui_lock:
# ---> 53             super().render()
#      54
#      55         glfw.poll_events()
#
# ~/work/external/mujoco-py/mujoco_py/mjrendercontext.pyx in mujoco_py.cymj.MjRenderContextWindow.render()
#
# ~/miniconda3/envs/baselines/lib/python3.6/site-packages/glfw/__init__.py in swap_buffers(window)
#    2237 _glfw.glfwSwapBuffers.restype = None
#    2238 _glfw.glfwSwapBuffers.argtypes = [ctypes.POINTER(_GLFWwindow)]
# -> 2239 def swap_buffers(window):
#    2240     """
#    2241     Swaps the front and back buffers of the specified window.
#
# KeyboardInterrupt:

# %%
for post_name in ['standard' ,'rmul']: #seed = 10
    for run in [0,1,2,3,4]:
        o,a,r,l,_ = do_rollout(env,policy_dict[post_name][seed])

        #print("reward:", sum(r))
        #print("variation_dim: ", variation_dim(o))
        #print("roughness: ", rough_measure(o))
        #plt.plot(o)
        #plt.figure()
        #plt.plot(a)

        import scipy.io 
        import os

        o = np.array(o)
        a = np.array(a)
        r = np.array(r)
        os.makedirs(f"./j/exp_{name}/post_{post_name}/seed_{seed}", exist_ok=True)
        scipy.io.savemat(f"./j/exp_{name}/post_{post_name}/seed_{seed}/run_{run}.mat", mdict = {"obs":o, "act":a, "rew":r})

# %%
env.close()
